# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np

# %%
params_config = {
    'Rescue Cost ($c_h$)': 'Sensitivity_Data_ch.csv',
    'Build Cost ($c_b$)': 'Sensitivity_Data_cb.csv',
    'Maintain Cost ($c_m$)': 'Sensitivity_Data_cm.csv',
    'Charge Cost ($c_c$)': 'Sensitivity_Data_cc.csv'
}

colors = ['#2ca02c', '#d62728', '#1f77b4', '#ff7f0e']
markers = ['^', 'o', 's', 'D']

fig, ax = plt.subplots(figsize=(10, 6), dpi=150)
x_ticks = [-20, -10, 0, 10, 20]

for i, (label, file) in enumerate(params_config.items()):
    df = pd.read_csv(file)
    costs = df['Total_Cost'].values

    base_cost = costs[2]

    # Calculate percentage change
    percent_changes = [(c - base_cost) / base_cost * 100 for c in costs]

    # Plot the sensitivity curve for this parameter
    ax.plot(x_ticks, percent_changes, label=label, color=colors[i],
            marker=markers[i], linewidth=2.5, markersize=8)


ax.axhline(0, color='black', linestyle='-', linewidth=1.5, alpha=0.6)
ax.axvline(0, color='black', linestyle='-', linewidth=1.5, alpha=0.6)

ax.set_xlabel('Parameter Variation from Baseline (%)', fontsize=12, fontweight='bold')
ax.set_ylabel('Total System Cost Change (%)', fontsize=12, fontweight='bold')
ax.set_xticks(x_ticks)
ax.set_xticklabels([f"{x}%" for x in x_ticks])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.grid(True, linestyle=':', alpha=0.6)

ax.legend(loc='upper left', frameon=True, shadow=True, fontsize=11)

fig.tight_layout()

# Saving the figure
plt.savefig("Sensitivity_SpiderPlot_Overall.pdf", format='pdf')
plt.show()
